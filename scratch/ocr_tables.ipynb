# %%
import sys

sys.path.append('..')

# %%
import csv
from io import StringIO
from pathlib import Path

import easyocr
import enchant
import pytesseract
from PIL import Image

from digi_leap.ocr import ocr_label
from digi_leap.ocr_score import score_easyocr

# %%
DATA_DIR = Path('..') / 'data'
LABELS_DIR = DATA_DIR / 'labels' / 'typewritten'
# LABELS_DIR = DATA_DIR / 'labels' / 'handwritten'

# %%
IMAGES = sorted(LABELS_DIR.glob('*.jpg'))

LABEL = IMAGES[1]

# %%
EASY_OCR = easyocr.Reader(['en'])

# %%
image = Image.open(LABEL)
# image

# %%
data1 = pytesseract.image_to_data(image)
print(data1)
# Out:
# level	page_num	block_num	par_num	line_num	word_num	left	top	width	height	conf	text
# 1	1	0	0	0	0	0	0	1335	786	-1
# 2	1	1	0	0	0	132	127	988	90	-1
# 3	1	1	1	0	0	132	127	988	90	-1
# 4	1	1	1	1	0	132	127	988	40	-1
# 5	1	1	1	1	1	132	135	297	32	96	APPALACHIAN
# 5	1	1	1	1	2	449	132	134	31	95	STATE
# 5	1	1	1	1	3	604	129	250	34	95	UNIVERSITY
# 5	1	1	1	1	4	873	127	247	33	96	HERBARIUM
# 4	1	1	1	2	0	283	183	536	34	-1
# 5	1	1	1	2	1	283	179	163	45	96	PLANTS
# 5	1	1	1	2	2	464	185	55	31	89	OF
# 5	1	1	1	2	3	589	183	230	30	93	Tennessee
# 2	1	2	0	0	0	248	261	591	54	-1
# 3	1	2	1	0	0	248	261	591	54	-1
# 4	1	2	1	1	0	248	261	591	54	-1
# 5	1	2	1	1	1	248	270	176	33	85	plenium
# 5	1	2	1	1	2	459	261	302	54	88	ruta-muraria
# 5	1	2	1	1	3	794	263	45	32	59	die
# 2	1	3	0	0	0	196	281	83	37	-1
# 3	1	3	1	0	0	196	281	83	37	-1
# 4	1	3	1	1	0	196	281	83	37	-1
# 5	1	3	1	1	1	196	281	83	37	95
# 2	1	4	0	0	0	132	418	999	266	-1
# 3	1	4	1	0	0	197	418	879	42	-1
# 4	1	4	1	1	0	197	418	879	42	-1
# 5	1	4	1	1	1	197	426	229	32	90	Limestone
# 5	1	4	1	1	2	460	421	148	33	96	cliffs
# 5	1	4	1	1	3	643	421	97	39	96	just
# 5	1	4	1	1	4	771	419	125	31	96	above
# 5	1	4	1	1	5	930	418	146	37	96	water,
# 3	1	4	2	0	0	132	471	999	213	-1
# 4	1	4	2	1	0	204	471	927	45	-1
# 5	1	4	2	1	1	204	479	249	37	31	Shicamauga
# 5	1	4	2	1	2	483	475	122	39	93	Lake,
# 5	1	4	2	1	3	639	472	210	32	90	Hammlton
# 5	1	4	2	1	4	880	471	91	40	83	Co.,
# 5	1	4	2	1	5	1016	471	115	30	94	Tenn.
# 4	1	4	2	2	0	133	531	818	55	-1
# 5	1	4	2	2	1	133	535	59	51	91	No.
# 5	1	4	2	2	2	673	537	82	32	91	Date
# 5	1	4	2	2	3	802	531	149	38	81	6-2-68
# 4	1	4	2	3	0	132	591	237	41	-1
# 5	1	4	2	3	1	132	591	179	32	96	Collected
# 5	1	4	2	3	2	331	592	38	40	96	by
# 4	1	4	2	4	0	134	643	265	41	-1
# 5	1	4	2	4	1	134	643	207	31	96	Determined
# 5	1	4	2	4	2	361	643	38	41	96	by
# 2	1	5	0	0	0	488	601	359	37	-1
# 3	1	5	1	0	0	488	601	359	37	-1
# 4	1	5	1	1	0	488	601	359	37	-1
# 5	1	5	1	1	1	488	606	126	32	94	Marie
# 5	1	5	1	1	2	645	605	41	32	65	1.
# 5	1	5	1	1	3	720	601	127	34	95	Hicks

# %%
table1 = []
with StringIO(data1) as str_file:
    reader = csv.DictReader(str_file, delimiter='\t')
    for row in reader:
        conf = float(row['conf'])
        if conf < 0:
            continue
        left = int(row['left'])
        top = int(row['top'])
        table1.append({
            'text': row['text'],
            'conf': conf / 100.0,
            'left': left,
            'top': top,
            'right': left + int(row['width']) - 1,
            'bottom': top + int(row['height']) - 1,
        })
table1
# Out:
# [{'text': 'APPALACHIAN',
#   'conf': 0.96,
#   'left': 132,
#   'top': 135,
#   'right': 428,
#   'bottom': 166},
#  {'text': 'STATE',
#   'conf': 0.95,
#   'left': 449,
#   'top': 132,
#   'right': 582,
#   'bottom': 162},
#  {'text': 'UNIVERSITY',
#   'conf': 0.95,
#   'left': 604,
#   'top': 129,
#   'right': 853,
#   'bottom': 162},
#  {'text': 'HERBARIUM',
#   'conf': 0.96,
#   'left': 873,
#   'top': 127,
#   'right': 1119,
#   'bottom': 159},
#  {'text': 'PLANTS',
#   'conf': 0.96,
#   'left': 283,
#   'top': 179,
#   'right': 445,
#   'bottom': 223},
#  {'text': 'OF',
#   'conf': 0.89,
#   'left': 464,
#   'top': 185,
#   'right': 518,
#   'bottom': 215},
#  {'text': 'Tennessee',
#   'conf': 0.93,
#   'left': 589,
#   'top': 183,
#   'right': 818,
#   'bottom': 212},
#  {'text': 'plenium',
#   'conf': 0.85,
#   'left': 248,
#   'top': 270,
#   'right': 423,
#   'bottom': 302},
#  {'text': 'ruta-muraria',
#   'conf': 0.88,
#   'left': 459,
#   'top': 261,
#   'right': 760,
#   'bottom': 314},
#  {'text': 'die',
#   'conf': 0.59,
#   'left': 794,
#   'top': 263,
#   'right': 838,
#   'bottom': 294},
#  {'text': ' ',
#   'conf': 0.95,
#   'left': 196,
#   'top': 281,
#   'right': 278,
#   'bottom': 317},
#  {'text': 'Limestone',
#   'conf': 0.9,
#   'left': 197,
#   'top': 426,
#   'right': 425,
#   'bottom': 457},
#  {'text': 'cliffs',
#   'conf': 0.96,
#   'left': 460,
#   'top': 421,
#   'right': 607,
#   'bottom': 453},
#  {'text': 'just',
#   'conf': 0.96,
#   'left': 643,
#   'top': 421,
#   'right': 739,
#   'bottom': 459},
#  {'text': 'above',
#   'conf': 0.96,
#   'left': 771,
#   'top': 419,
#   'right': 895,
#   'bottom': 449},
#  {'text': 'water,',
#   'conf': 0.96,
#   'left': 930,
#   'top': 418,
#   'right': 1075,
#   'bottom': 454},
#  {'text': 'Shicamauga',
#   'conf': 0.31,
#   'left': 204,
#   'top': 479,
#   'right': 452,
#   'bottom': 515},
#  {'text': 'Lake,',
#   'conf': 0.93,
#   'left': 483,
#   'top': 475,
#   'right': 604,
#   'bottom': 513},
#  {'text': 'Hammlton',
#   'conf': 0.9,
#   'left': 639,
#   'top': 472,
#   'right': 848,
#   'bottom': 503},
#  {'text': 'Co.,',
#   'conf': 0.83,
#   'left': 880,
#   'top': 471,
#   'right': 970,
#   'bottom': 510},
#  {'text': 'Tenn.',
#   'conf': 0.94,
#   'left': 1016,
#   'top': 471,
#   'right': 1130,
#   'bottom': 500},
#  {'text': 'No.',
#   'conf': 0.91,
#   'left': 133,
#   'top': 535,
#   'right': 191,
#   'bottom': 585},
#  {'text': 'Date',
#   'conf': 0.91,
#   'left': 673,
#   'top': 537,
#   'right': 754,
#   'bottom': 568},
#  {'text': '6-2-68',
#   'conf': 0.81,
#   'left': 802,
#   'top': 531,
#   'right': 950,
#   'bottom': 568},
#  {'text': 'Collected',
#   'conf': 0.96,
#   'left': 132,
#   'top': 591,
#   'right': 310,
#   'bottom': 622},
#  {'text': 'by',
#   'conf': 0.96,
#   'left': 331,
#   'top': 592,
#   'right': 368,
#   'bottom': 631},
#  {'text': 'Determined',
#   'conf': 0.96,
#   'left': 134,
#   'top': 643,
#   'right': 340,
#   'bottom': 673},
#  {'text': 'by',
#   'conf': 0.96,
#   'left': 361,
#   'top': 643,
#   'right': 398,
#   'bottom': 683},
#  {'text': 'Marie',
#   'conf': 0.94,
#   'left': 488,
#   'top': 606,
#   'right': 613,
#   'bottom': 637},
#  {'text': '1.',
#   'conf': 0.65,
#   'left': 645,
#   'top': 605,
#   'right': 685,
#   'bottom': 636},
#  {'text': 'Hicks',
#   'conf': 0.95,
#   'left': 720,
#   'top': 601,
#   'right': 846,
#   'bottom': 634}]

# %%
data2 = EASY_OCR.readtext(image)
data2
# Out:
# [([[120, 118], [1128, 118], [1128, 174], [120, 174]],
#   'APPALACHIAV STATE UNIVERSITY HERBARIUM',
#   0.8233845794609377),
#  ([[275, 179], [521, 179], [521, 223], [275, 223]],
#   'PLAVTS OF',
#   0.6838808285523854),
#  ([[584, 178], [827, 178], [827, 223], [584, 223]],
#   'Tennessee',
#   0.9627254164393629),
#  ([[182, 262], [432, 262], [432, 318], [182, 318]],
#   'Asplenium',
#   0.5222644995959352),
#  ([[450, 258], [770, 258], [770, 312], [450, 312]],
#   'ruta_muraria',
#   0.9767573634667366),
#  ([[787, 259], [823, 259], [823, 299], [787, 299]], 'L', 0.41991813890533436),
#  ([[187, 418], [435, 418], [435, 470], [187, 470]],
#   'Limestone',
#   0.9995719531047783),
#  ([[450, 411], [746, 411], [746, 466], [450, 466]],
#   'cliffs just',
#   0.9949124980652062),
#  ([[765, 413], [903, 413], [903, 455], [765, 455]],
#   'above',
#   0.999736048101681),
#  ([[926, 422], [980, 422], [980, 454], [926, 454]], 'Wa', 0.8444103066260022),
#  ([[973, 410], [1086, 410], [1086, 463], [973, 463]],
#   'ter ,',
#   0.820725203986585),
#  ([[193, 463], [617, 463], [617, 523], [193, 523]],
#   'Chi camauga Lake ,',
#   0.6695555228136971),
#  ([[631, 465], [855, 465], [855, 509], [631, 509]],
#   'Hamilton',
#   0.5607125494040854),
#  ([[875, 467], [933, 467], [933, 507], [875, 507]], 'Co', 0.9370220491325765),
#  ([[955, 489], [975, 489], [975, 513], [955, 513]], '9', 0.5854398535002616),
#  ([[1009, 467], [1119, 467], [1119, 507], [1009, 507]],
#   'Fenn',
#   0.4423048762423983),
#  ([[125, 533], [201, 533], [201, 578], [125, 578]], 'Vo.', 0.8110770206453882),
#  ([[664, 530], [765, 530], [765, 579], [664, 579]],
#   'Date',
#   0.9999912977218628),
#  ([[793, 523], [958, 523], [958, 577], [793, 577]],
#   '6-2-68',
#   0.9998861177891016),
#  ([[125, 585], [378, 585], [378, 638], [125, 638]],
#   'Collected by',
#   0.7978186803832925),
#  ([[476, 597], [672, 597], [672, 645], [476, 645]],
#   'Marie T,',
#   0.6741832730955206),
#  ([[709, 592], [856, 592], [856, 642], [709, 642]],
#   'Hicks',
#   0.9890165251778545),
#  ([[126, 638], [406, 638], [406, 690], [126, 690]],
#   'Determined by',
#   0.9960375779069633)]

# %%
table2 = []
for item in data2:
    pos = item[0]
    table2.append({
        'text': item[1],
        'conf': item[2],
        'left': pos[0][0],
        'top': pos[0][1],
        'right': pos[1][0],
        'bottom': pos[2][1],
    })
table2
# Out:
# [{'text': 'APPALACHIAV STATE UNIVERSITY HERBARIUM',
#   'conf': 0.8233845794609377,
#   'left': 120,
#   'top': 118,
#   'right': 1128,
#   'bottom': 174},
#  {'text': 'PLAVTS OF',
#   'conf': 0.6838808285523854,
#   'left': 275,
#   'top': 179,
#   'right': 521,
#   'bottom': 223},
#  {'text': 'Tennessee',
#   'conf': 0.9627254164393629,
#   'left': 584,
#   'top': 178,
#   'right': 827,
#   'bottom': 223},
#  {'text': 'Asplenium',
#   'conf': 0.5222644995959352,
#   'left': 182,
#   'top': 262,
#   'right': 432,
#   'bottom': 318},
#  {'text': 'ruta_muraria',
#   'conf': 0.9767573634667366,
#   'left': 450,
#   'top': 258,
#   'right': 770,
#   'bottom': 312},
#  {'text': 'L',
#   'conf': 0.41991813890533436,
#   'left': 787,
#   'top': 259,
#   'right': 823,
#   'bottom': 299},
#  {'text': 'Limestone',
#   'conf': 0.9995719531047783,
#   'left': 187,
#   'top': 418,
#   'right': 435,
#   'bottom': 470},
#  {'text': 'cliffs just',
#   'conf': 0.9949124980652062,
#   'left': 450,
#   'top': 411,
#   'right': 746,
#   'bottom': 466},
#  {'text': 'above',
#   'conf': 0.999736048101681,
#   'left': 765,
#   'top': 413,
#   'right': 903,
#   'bottom': 455},
#  {'text': 'Wa',
#   'conf': 0.8444103066260022,
#   'left': 926,
#   'top': 422,
#   'right': 980,
#   'bottom': 454},
#  {'text': 'ter ,',
#   'conf': 0.820725203986585,
#   'left': 973,
#   'top': 410,
#   'right': 1086,
#   'bottom': 463},
#  {'text': 'Chi camauga Lake ,',
#   'conf': 0.6695555228136971,
#   'left': 193,
#   'top': 463,
#   'right': 617,
#   'bottom': 523},
#  {'text': 'Hamilton',
#   'conf': 0.5607125494040854,
#   'left': 631,
#   'top': 465,
#   'right': 855,
#   'bottom': 509},
#  {'text': 'Co',
#   'conf': 0.9370220491325765,
#   'left': 875,
#   'top': 467,
#   'right': 933,
#   'bottom': 507},
#  {'text': '9',
#   'conf': 0.5854398535002616,
#   'left': 955,
#   'top': 489,
#   'right': 975,
#   'bottom': 513},
#  {'text': 'Fenn',
#   'conf': 0.4423048762423983,
#   'left': 1009,
#   'top': 467,
#   'right': 1119,
#   'bottom': 507},
#  {'text': 'Vo.',
#   'conf': 0.8110770206453882,
#   'left': 125,
#   'top': 533,
#   'right': 201,
#   'bottom': 578},
#  {'text': 'Date',
#   'conf': 0.9999912977218628,
#   'left': 664,
#   'top': 530,
#   'right': 765,
#   'bottom': 579},
#  {'text': '6-2-68',
#   'conf': 0.9998861177891016,
#   'left': 793,
#   'top': 523,
#   'right': 958,
#   'bottom': 577},
#  {'text': 'Collected by',
#   'conf': 0.7978186803832925,
#   'left': 125,
#   'top': 585,
#   'right': 378,
#   'bottom': 638},
#  {'text': 'Marie T,',
#   'conf': 0.6741832730955206,
#   'left': 476,
#   'top': 597,
#   'right': 672,
#   'bottom': 645},
#  {'text': 'Hicks',
#   'conf': 0.9890165251778545,
#   'left': 709,
#   'top': 592,
#   'right': 856,
#   'bottom': 642},
#  {'text': 'Determined by',
#   'conf': 0.9960375779069633,
#   'left': 126,
#   'top': 638,
#   'right': 406,
#   'bottom': 690}]
