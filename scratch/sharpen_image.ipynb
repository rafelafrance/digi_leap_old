# %%
import sys

sys.path.append('..')

# %%
from pathlib import Path
from random import sample

import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
from ipywidgets import interact
from PIL import Image, ImageEnhance
from skimage import filters, morphology as morph, util
from tqdm import tqdm

import digi_leap.label_image as li
from digi_leap.ocr_score import ocr_score
from digi_leap.ocr import ocr_label, WINDOW_SIZE, K

# %%
DATA_DIR = Path('..') / 'data'
LABELS_DIR = DATA_DIR / 'labels' / 'typewritten'
# LABELS_DIR = DATA_DIR / 'labels' / 'handwritten'
TARGET = LABELS_DIR / '11780338.jpg'

# %%
image = Image.open(TARGET).convert('L')
display(image)
# Out:
# <PIL.Image.Image image mode=L size=985x607 at 0x7FBC44DF1520>

# %%
sharpener = ImageEnhance.Sharpness(image)

# %%
# image_5 = sharpener.enhance(5.0)
# display(image_5)

# score_5 = ocr_score(image_5)
# print(score_5)

# print(score_5.text)

# %%
image_10 = sharpener.enhance(10.0)
# display(image_10)

score_10 = ocr_score(image_10)
print(score_10)

print(score_10.text)
# Out:
# self.score=(35, 64.81)
# self.found=35
# self.percent=64.81
# self.total=54
# self.stem=''
# self.method=[]
# self.engine='tesseract'
#
# ERBARIUM OF THE UNIVERSITY OF ARKANSAS
# PLANTS OF ARKANSAS
#
# a eh (Metial Mieren,
# ver, Fopene M weit.) A, i, Beare
#
# Artenaee Oo,, Avkacean
# Veite Cver Refuge Fasalie Sage
#
# bet. G. 3, Sth
#
# Coll. 4, #. Lowke No. Hw
# Dete “ay lito,

# %%
image_x = sharpener.enhance(3.0)
binary = np.asarray(image_x).copy()
threshold = filters.threshold_sauvola(binary, window_size=WINDOW_SIZE, k=K)
binary = binary < threshold
binary = util.invert(binary)
display(li.to_pil(binary))

score_bin = ocr_score(binary)
print(score_bin)
print(score_bin.text)
# Out:
# <PIL.Image.Image image mode=1 size=985x607 at 0x7FBC2C502A90>
# self.score=(53, 69.74)
# self.found=53
# self.percent=69.74
# self.total=76
# self.stem=''
# self.method=[]
# self.engine='easyocr'
#
# 4," Mishiailiust ov tiie Umivknsny Qh' AmKANJY PLANTS OF AAKANSAS #Wt0be 4 #W ("ti#) [gafons 70# Ia [bile.) 1; 1. 1004+ 14#4*,39 Cu. A#bamml #E+ "V7v< %4 J+4 Dob . 3, blnl Coll 4' 0' , Ld# # Mu: 972) Dalv iwX 34 m4 Fou #iz 4

# %%
# image_15 = sharpener.enhance(15.0)
# display(image_15)

# score_15 = ocr_score(image_15)
# print(score_15)

# print(score_15.text)
